# %%
import pandas as pd

# %%
train_df = pd.read_csv('train_dataset.csv')
test_df = pd.read_csv('test_dataset.csv')

# %%
train_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.019913  0.050680  0.104809  0.070072 -0.035968 -0.026679 -0.024993
# 1 -0.012780 -0.044642  0.060618  0.052858  0.047965  0.029375 -0.017629
# 2  0.038076  0.050680  0.008883  0.042529 -0.042848 -0.021042 -0.039719
# 3 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 4 -0.023677 -0.044642  0.045529  0.090729 -0.018080 -0.035447  0.070730
#
#          s4        s5        s6  target
# 0 -0.002592  0.003709  0.040343   321.0
# 1  0.034309  0.070207  0.007207   215.0
# 2 -0.002592 -0.018114  0.007207   127.0
# 3 -0.002592 -0.038460 -0.038357    64.0
# 4 -0.039493 -0.034522 -0.009362   175.0

# %%
test_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
# 2  0.027178  0.050680  0.017506 -0.033213 -0.007073  0.045972 -0.065491
# 3  0.045341  0.050680  0.060618  0.031065  0.028702 -0.047347 -0.054446
# 4 -0.067268  0.050680 -0.012673 -0.040099 -0.015328  0.004636 -0.058127
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.002592  0.067737 -0.013504   310.0
# 2  0.071210 -0.096435 -0.059067    69.0
# 3  0.071210  0.133597  0.135612   245.0
# 4  0.034309  0.019196 -0.034215   202.0

# %%
y_train = train_df['target']
X_train = train_df.drop(columns=['target'])

y_test = test_df['target']
X_test = test_df.drop(columns=['target'])

# %%
# entrenar modelo de regresion
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#evaluar metricas
y_pred = model.predict(X_train)
mse = mean_squared_error(y_train, y_pred)
print(f'MSE: {mse}')
mae = mean_absolute_error(y_train, y_pred)
print(f'MAE: {mae}')
r2 = r2_score(y_train, y_pred)
print(f'R2: {r2}')
# Out:
# MSE: 2902.0483821109683
# MAE: 43.72789618474123
# R2: 0.484122067464441

# %%
# evaluar modelo
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'MSE: {mse}')
mae = mean_absolute_error(y_test, y_pred)
print(f'MAE: {mae}')
r2 = r2_score(y_test, y_pred)
print(f'R2: {r2}')
# Out:
# MSE: 2855.8184535056253
# MAE: 43.143476218056364
# R2: 0.5690847834753974

# %%
# guardar modelo en .pickle
import pickle

with open('model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)
